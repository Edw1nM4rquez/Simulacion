# %%
#Deber 1 
import random as r
import collections
import matplotlib.pyplot as plt

sumatoria = []

Items = [100, 1000, 10000, 100000]

for j in range(0, len(Items)):
    sumatoria.clear()
    print("Valor a continuacion: ", Items[j])
    for i in range(Items[j]):
        a = r.randint(1, 6)
        b = r.randint(1, 6)
        sumatoria.append(a+b)

    counter = collections.Counter(sumatoria)

    print('Frecuencias (Sumatorias de los dados): ', counter,"\n")
    
    plt.bar(counter.keys(), counter.values(), color='#F2AB6D', edgecolor = 'black')
    
    plt.title('Frecuencia-%s' % Valores[j])

    plt.xlabel('Valores')

    plt.ylabel('Sumatoria')    
    
    plt.show()
# Out:
# Valor a continuacion:  100
# Frecuencias (Sumatorias de los dados):  Counter({6: 20, 7: 19, 8: 16, 5: 15, 10: 9, 9: 6, 4: 6, 3: 5, 11: 3, 2: 1})
# Valor a continuacion:  1000
# Frecuencias (Sumatorias de los dados):  Counter({7: 163, 6: 150, 8: 137, 9: 119, 5: 109, 10: 80, 4: 79, 11: 56, 3: 53, 2: 29, 12: 25})
# Valor a continuacion:  10000
# Frecuencias (Sumatorias de los dados):  Counter({7: 1612, 8: 1350, 6: 1336, 9: 1169, 5: 1099, 10: 863, 4: 802, 3: 586, 11: 578, 2: 309, 12: 296})
# Valor a continuacion:  100000
# Frecuencias (Sumatorias de los dados):  Counter({7: 16440, 6: 14111, 8: 13979, 5: 11133, 9: 11102, 4: 8263, 10: 8210, 3: 5625, 11: 5581, 2: 2815, 12: 2741})

# %%
3
